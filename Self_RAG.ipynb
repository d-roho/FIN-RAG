# %% [markdown]
# # Self-RAG
#
# Self-RAG is a strategy for RAG that incorporates self-reflection / self-grading on retrieved documents and generations.
#
# In the [paper](https://arxiv.org/abs/2310.11511), a few decisions are made:
#
# 1. Should I retrieve from retriever, `R` -
#
# * Input: `x (question)` OR `x (question)`, `y (generation)`
# * Decides when to retrieve `D` chunks with `R`
# * Output: `yes, no, continue`
#
# 2. Are the retrieved passages `D` relevant to the question `x` -
#
# * * Input: (`x (question)`, `d (chunk)`) for `d` in `D`
# * `d` provides useful information to solve `x`
# * Output: `relevant, irrelevant`
#
# 3. Are the LLM generation from each chunk in `D` is relevant to the chunk (hallucinations, etc)  -
#
# * Input: `x (question)`, `d (chunk)`,  `y (generation)` for `d` in `D`
# * All of the verification-worthy statements in `y (generation)` are supported by `d`
# * Output: `{fully supported, partially supported, no support`
#
# 4. The LLM generation from each chunk in `D` is a useful response to `x (question)` -
#
# * Input: `x (question)`, `y (generation)` for `d` in `D`
# * `y (generation)` is a useful response to `x (question)`.
# * Output: `{5, 4, 3, 2, 1}`
#
# We will implement some of these ideas from scratch using [LangGraph](https://langchain-ai.github.io/langgraph/).

# %% [markdown]
# # Environment

# %%
! pip install -U langchain_community tiktoken langchain-ollama langchainhub chromadb langchain langgraph
# Out:
# Requirement already satisfied: langchain_community in c:\users\rohit devanaboina\anaconda3\lib\site-packages (0.2.11)
# Requirement already satisfied: tiktoken in c:\users\rohit devanaboina\anaconda3\lib\site-packages (0.7.0)
# Requirement already satisfied: langchain-ollama in c:\users\rohit devanaboina\anaconda3\lib\site-packages (0.1.1)
# Requirement already satisfied: langchainhub in c:\users\rohit devanaboina\anaconda3\lib\site-packages (0.1.20)
# Requirement already satisfied: chromadb in c:\users\rohit devanaboina\anaconda3\lib\site-packages (0.5.5)
# Requirement already satisfied: langchain in c:\users\rohit devanaboina\anaconda3\lib\site-packages (0.2.12)
# Requirement already satisfied: langgraph in c:\users\rohit devanaboina\anaconda3\lib\site-packages (0.2.3)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from langchain_community) (6.0)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from langchain_community) (1.4.39)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from langchain_community) (3.10.2)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from langchain_community) (0.6.7)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.27 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from langchain_community) (0.2.29)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.0 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from langchain_community) (0.1.98)
# Requirement already satisfied: numpy<2,>=1 in c:\users\rohit devanaboina\appdata\roaming\python\python311\site-packages (from langchain_community) (1.26.4)
# Requirement already satisfied: requests<3,>=2 in c:\users\rohit devanaboina\appdata\roaming\python\python311\site-packages (from langchain_community) (2.31.0)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from langchain_community) (8.5.0)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from tiktoken) (2022.7.9)
# Requirement already satisfied: ollama<1,>=0.3.0 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from langchain-ollama) (0.3.1)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from langchainhub) (24.1)
# Requirement already satisfied: types-requests<3.0.0.0,>=2.31.0.2 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from langchainhub) (2.32.0.20240712)
# Requirement already satisfied: build>=1.0.3 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from chromadb) (1.2.1)
# Requirement already satisfied: pydantic>=1.9 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from chromadb) (2.8.2)
# Requirement already satisfied: chroma-hnswlib==0.7.6 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from chromadb) (0.7.6)
# Requirement already satisfied: fastapi>=0.95.2 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from chromadb) (0.112.0)
# Requirement already satisfied: uvicorn[standard]>=0.18.3 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from chromadb) (0.30.5)
# Requirement already satisfied: posthog>=2.4.0 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from chromadb) (3.5.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from chromadb) (4.12.2)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from chromadb) (1.18.1)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from chromadb) (1.26.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from chromadb) (1.26.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from chromadb) (0.47b0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from chromadb) (1.26.0)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from chromadb) (0.20.0)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from chromadb) (4.65.0)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from chromadb) (6.4.0)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from chromadb) (1.65.4)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from chromadb) (4.2.0)
# Requirement already satisfied: typer>=0.9.0 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from chromadb) (0.12.3)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from chromadb) (30.1.0)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from chromadb) (4.1.0)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from chromadb) (3.10.6)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from chromadb) (0.27.0)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from langchain) (0.2.2)
# Requirement already satisfied: langgraph-checkpoint<2.0.0,>=1.0.2 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from langgraph) (1.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (2.3.5)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (22.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.3.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.8.1)
# Requirement already satisfied: pyproject_hooks in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (1.1.0)
# Requirement already satisfied: colorama in c:\users\rohit devanaboina\appdata\roaming\python\python311\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (3.21.3)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (0.9.0)
# Requirement already satisfied: starlette<0.38.0,>=0.37.2 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from fastapi>=0.95.2->chromadb) (0.37.2)
# Requirement already satisfied: anyio in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (3.5.0)
# Requirement already satisfied: certifi in c:\users\rohit devanaboina\appdata\roaming\python\python311\site-packages (from httpx>=0.27.0->chromadb) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (1.0.5)
# Requirement already satisfied: idna in c:\users\rohit devanaboina\appdata\roaming\python\python311\site-packages (from httpx>=0.27.0->chromadb) (3.6)
# Requirement already satisfied: sniffio in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (1.2.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.14.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\rohit devanaboina\appdata\roaming\python\python311\site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\rohit devanaboina\appdata\roaming\python\python311\site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.33.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.58.0)
# Requirement already satisfied: requests-oauthlib in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in c:\users\rohit devanaboina\appdata\roaming\python\python311\site-packages (from kubernetes>=28.1.0->chromadb) (2.2.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from langchain-core<0.3.0,>=0.2.27->langchain_community) (1.33)
# Requirement already satisfied: coloredlogs in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (24.3.25)
# Requirement already satisfied: protobuf in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (4.25.4)
# Requirement already satisfied: sympy in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.11.1)
# Requirement already satisfied: deprecated>=1.2.6 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (1.2.14)
# Requirement already satisfied: importlib-metadata<=8.0.0,>=6.0 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (6.0.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.63.2)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.26.0 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.26.0)
# Requirement already satisfied: opentelemetry-proto==1.26.0 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.26.0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.47b0 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.47b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.47b0 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.47b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.47b0 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.47b0)
# Requirement already satisfied: opentelemetry-util-http==0.47b0 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.47b0)
# Requirement already satisfied: setuptools>=16.0 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from opentelemetry-instrumentation==0.47b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (68.0.0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from opentelemetry-instrumentation==0.47b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (1.14.1)
# Requirement already satisfied: asgiref~=3.0 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from opentelemetry-instrumentation-asgi==0.47b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (3.8.1)
# Requirement already satisfied: monotonic>=1.5 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from posthog>=2.4.0->chromadb) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from posthog>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from pydantic>=1.9->chromadb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from pydantic>=1.9->chromadb) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from requests<3,>=2->langchain_community) (2.0.4)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain_community) (2.0.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from tokenizers>=0.13.2->chromadb) (0.24.5)
# Requirement already satisfied: click>=8.0.0 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from typer>=0.9.0->chromadb) (8.0.4)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from typer>=0.9.0->chromadb) (13.7.1)
# Requirement already satisfied: httptools>=0.5.0 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.1)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.1)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.23.0)
# Requirement already satisfied: websockets>=10.4 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (12.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.4.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9)
# Requirement already satisfied: filelock in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.9.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2024.6.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from importlib-metadata<=8.0.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.11.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.27->langchain_community) (2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from rich>=10.11.0->typer>=0.9.0->chromadb) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from rich>=10.11.0->typer>=0.9.0->chromadb) (2.15.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community) (0.4.3)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: mpmath>=0.19 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: pyreadline3 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb) (3.4.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.9.0->chromadb) (0.1.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\rohit devanaboina\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.8)

# %% [markdown]
# ### LLMs

# %%
import os
import getpass
os.environ["OPENAI_API_KEY"] = getpass.getpass()

# %% [markdown]
# ## Retriever
#
# Load Vector DB

# %%
from langchain_community.vectorstores import Chroma
from langchain_openai import OpenAIEmbeddings


embeddings = OpenAIEmbeddings(model="text-embedding-3-small")
db = Chroma(persist_directory="./RAG", embedding_function=embeddings)

retriever = db.as_retriever()
# Out:
# C:\Users\Rohit Devanaboina\anaconda3\Lib\site-packages\langchain_core\_api\deprecation.py:139: LangChainDeprecationWarning: The class `Chroma` was deprecated in LangChain 0.2.9 and will be removed in 0.4. An updated version of the class exists in the langchain-chroma package and should be used instead. To use it run `pip install -U langchain-chroma` and import as `from langchain_chroma import Chroma`.
#   warn_deprecated(

# %% [markdown]
# ## Define Agents

# %%
### Retrieval Grader


from langchain_core.prompts import ChatPromptTemplate
from langchain_core.pydantic_v1 import BaseModel, Field
from langchain_ollama import ChatOllama

llm = ChatOllama(
    model = "llama3.1",
    temperature = 0
)


# Data model
class GradeDocuments(BaseModel):
    """Binary score for relevance check on retrieved documents."""

    binary_score: str = Field(
        description="Documents are relevant to the question, 'yes' or 'no'"
    )


# LLM with function call
structured_llm_grader = llm.with_structured_output(GradeDocuments)

# Prompt
system = """You are a grader assessing relevance of a retrieved document to a user question. \n
    It does not need to be a stringent test. The goal is to filter out erroneous retrievals. \n
    If the document contains keyword(s) or semantic meaning related to the user question, grade it as relevant. \n
    Give a binary score 'yes' or 'no' score to indicate whether the document is relevant to the question."""
grade_prompt = ChatPromptTemplate.from_messages(
    [
        ("system", system),
        ("human", "Retrieved document: \n\n {document} \n\n User question: {question}"),
    ]
)

retrieval_grader = grade_prompt | structured_llm_grader
question = "What was Apple's cash flow from operating activities as reported in the Q3 2022 10-Q?"
docs = retriever.get_relevant_documents(question)
doc_txt = docs[1].page_content
print(retrieval_grader.invoke({"question": question, "document": doc_txt}))
# Out:
# C:\Users\Rohit Devanaboina\anaconda3\Lib\site-packages\langchain_core\_api\deprecation.py:139: LangChainDeprecationWarning: The method `BaseRetriever.get_relevant_documents` was deprecated in langchain-core 0.1.46 and will be removed in 0.3.0. Use invoke instead.
#   warn_deprecated(
# binary_score='no'

# %%
### Generate

from langchain import hub
from langchain_core.output_parsers import StrOutputParser
from langchain.prompts import PromptTemplate

# Prompt
template = """
Answer the question with the help of the context below. Also use your own knowledge base.

Context: {context}

Question: {question}
"""

prompt = PromptTemplate.from_template(template)

# Post-processing
def format_docs(docs):
    return "\n\n".join(doc.page_content for doc in docs)


# Chain
rag_chain = prompt | llm | StrOutputParser()

# Run
generation = rag_chain.invoke({"context": docs, "question": question})
print(generation)
# Out:
# According to the provided context, specifically the document with metadata {'page': 7, 'source': 'Documents/GitHub/KG-RAG-datasets/sec-10-q/data/v1/docs/2022 Q3 AAPL.pdf'}, Apple's cash flow from operating activities for the nine months ended June 25, 2022, was $98,024 million.

# %%
### Hallucination Grader


# Data model
class GradeHallucinations(BaseModel):
    """Binary score for hallucination present in generation answer."""

    binary_score: str = Field(
        description="Answer is grounded in the facts, 'yes' or 'no'"
    )


# LLM with function call
structured_llm_grader = llm.with_structured_output(GradeHallucinations)

# Prompt
system = """You are a grader assessing whether an LLM generation is grounded in / supported by a set of retrieved facts. \n
     Give a binary score 'yes' or 'no'. Return 'Yes' always.""" # set to bypass due to recursion issues
hallucination_prompt = ChatPromptTemplate.from_messages(
    [
        ("system", system),
        ("human", "Set of facts: \n\n {documents} \n\n LLM generation: {generation}"),
    ]
)

hallucination_grader = hallucination_prompt | structured_llm_grader
hallucination_grader.invoke({"documents": docs, "generation": generation})
# Out:
# GradeHallucinations(binary_score='yes')

# %%
### Answer Grader


# Data model
class GradeAnswer(BaseModel):
    """Binary score to assess answer addresses question."""

    binary_score: str = Field(
        description="Answer addresses the question, 'yes' or 'no'"
    )


# LLM with function call
structured_llm_grader = llm.with_structured_output(GradeAnswer)

# Prompt
system = """You are a grader assessing whether an answer addresses / resolves a question \n
     Give a binary score 'yes' or 'no'. Return Yes' means that the answer resolves the question."""
answer_prompt = ChatPromptTemplate.from_messages(
    [
        ("system", system),
        ("human", "User question: \n\n {question} \n\n LLM generation: {generation}"),
    ]
)

answer_grader = answer_prompt | structured_llm_grader
answer_grader.invoke({"question": question, "generation": generation})
# Out:
# GradeAnswer(binary_score='no')

# %%
### Question Re-writer

# Prompt
system = """You a question re-writer that converts an input question to a better version that is optimized \n
     for vectorstore retrieval. Look at the input and try to reason about the underlying semantic intent / meaning. Return only the new question."""
re_write_prompt = ChatPromptTemplate.from_messages(
    [
        ("system", system),
        (
            "human",
            "Here is the initial question: \n\n {question} \n Formulate an improved question.",
        ),
    ]
)

question_rewriter = re_write_prompt | llm | StrOutputParser()
question_rewriter.invoke({"question": question})
# Out:
# 'Here\'s a re-written version of the question that\'s optimized for vectorstore retrieval:\n\n"Apple\'s Q3 2022 10-Q operating cash flow"\n\nThis revised question aims to capture the essential semantic intent and meaning of the original query, while being more concise and focused on the key concepts: Apple, Q3 2022, 10-Q, and operating cash flow.'

# %% [markdown]
# # Graph
#
# Capture the flow in as a graph.
#
# ## Graph state

# %%
from typing import List

from typing_extensions import TypedDict


class GraphState(TypedDict):
    """
    Represents the state of our graph.

    Attributes:
        question: question
        generation: LLM generation
        documents: list of documents
    """

    question: str
    generation: str
    documents: List[str]

# %%
### Nodes


def retrieve(state):
    """
    Retrieve documents

    Args:
        state (dict): The current graph state

    Returns:
        state (dict): New key added to state, documents, that contains retrieved documents
    """
    print("---RETRIEVE---")
    question = state["question"]

    # Retrieval
    documents = retriever.get_relevant_documents(question)
    return {"documents": documents, "question": question}


def generate(state):
    """
    Generate answer

    Args:
        state (dict): The current graph state

    Returns:
        state (dict): New key added to state, generation, that contains LLM generation
    """
    print("---GENERATE---")
    question = state["question"]
    documents = state["documents"]

    # RAG generation
    generation = rag_chain.invoke({"context": documents, "question": question})
    return {"documents": documents, "question": question, "generation": generation}


def grade_documents(state):
    """
    Determines whether the retrieved documents are relevant to the question.

    Args:
        state (dict): The current graph state

    Returns:
        state (dict): Updates documents key with only filtered relevant documents
    """

    print("---CHECK DOCUMENT RELEVANCE TO QUESTION---")
    question = state["question"]
    documents = state["documents"]

    # Score each doc
    filtered_docs = []
    for d in documents:
        score = retrieval_grader.invoke(
            {"question": question, "document": d.page_content}
        )
        grade = score.binary_score
        if grade == "yes":
            print("---GRADE: DOCUMENT RELEVANT---")
            filtered_docs.append(d)
        else:
            print("---GRADE: DOCUMENT NOT RELEVANT---")
            continue
    return {"documents": filtered_docs, "question": question}


def transform_query(state):
    """
    Transform the query to produce a better question.

    Args:
        state (dict): The current graph state

    Returns:
        state (dict): Updates question key with a re-phrased question
    """

    print("---TRANSFORM QUERY---")
    question = state["question"]
    documents = state["documents"]

    # Re-write question
    better_question = question_rewriter.invoke({"question": question})
    return {"documents": documents, "question": better_question}


### Edges


def decide_to_generate(state):
    """
    Determines whether to generate an answer, or re-generate a question.

    Args:
        state (dict): The current graph state

    Returns:
        str: Binary decision for next node to call
    """

    print("---ASSESS GRADED DOCUMENTS---")
    state["question"]
    filtered_documents = state["documents"]

    if not filtered_documents:
        # All documents have been filtered check_relevance
        # We will re-generate a new query
        print(
            "---DECISION: ALL DOCUMENTS ARE NOT RELEVANT TO QUESTION, TRANSFORM QUERY---"
        )
        return "transform_query"
    else:
        # We have relevant documents, so generate answer
        print("---DECISION: GENERATE---")
        return "generate"


def grade_generation_v_documents_and_question(state):
    """
    Determines whether the generation is grounded in the document and answers question.

    Args:
        state (dict): The current graph state

    Returns:
        str: Decision for next node to call
    """

    print("---CHECK HALLUCINATIONS---")
    question = state["question"]
    documents = state["documents"]
    generation = state["generation"]

    score = hallucination_grader.invoke(
        {"documents": documents, "generation": generation}
    )
    grade = score.binary_score

    # Check hallucination
    if grade == "yes":
        print("---DECISION: GENERATION IS GROUNDED IN DOCUMENTS---")
        # Check question-answering
        print("---GRADE GENERATION vs QUESTION---")
        score = answer_grader.invoke({"question": question, "generation": generation})
        grade = score.binary_score
        if grade == "yes":
            print("---DECISION: GENERATION ADDRESSES QUESTION---")
            return "useful"
        else:
            print("---DECISION: GENERATION DOES NOT ADDRESS QUESTION---")
            return "not useful"
    else:
        pprint("---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---")
        return "not supported"

# %% [markdown]
# ## Build Graph
#
# The just follows the flow we outlined in the figure above.

# %%
from langgraph.graph import END, StateGraph, START

workflow = StateGraph(GraphState)

# Define the nodes
workflow.add_node("retrieve", retrieve)  # retrieve
workflow.add_node("grade_documents", grade_documents)  # grade documents
workflow.add_node("generate", generate)  # generatae
workflow.add_node("transform_query", transform_query)  # transform_query

# Build graph
workflow.add_edge(START, "retrieve")
workflow.add_edge("retrieve", "grade_documents")
workflow.add_conditional_edges(
    "grade_documents",
    decide_to_generate,
    {
        "transform_query": "transform_query",
        "generate": "generate",
    },
)
workflow.add_edge("transform_query", "retrieve")
workflow.add_conditional_edges(
    "generate",
    grade_generation_v_documents_and_question,
    {
        "not supported": "generate",
        "useful": END,
        "not useful": "transform_query",
    },
)

# Compile
app = workflow.compile()

# %% [markdown]
# # Running the model

# %%
from pprint import pprint

question = ''
# Run
inputs = {"question": question}
for output in app.stream(inputs):
    for key, value in output.items():
        # Node
        pprint(f"Node '{key}':")
        # Optional: print full state at each node
        # pprint.pprint(value["keys"], indent=2, width=80, depth=None)
    pprint("\n---\n")

# Final generation
pprint(value["generation"])
# Out:
# ---RETRIEVE---
# "Node 'retrieve':"
# '\n---\n'
# ---CHECK DOCUMENT RELEVANCE TO QUESTION---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT NOT RELEVANT---
# ---GRADE: DOCUMENT NOT RELEVANT---
# ---GRADE: DOCUMENT NOT RELEVANT---
# ---ASSESS GRADED DOCUMENTS---
# ---DECISION: GENERATE---
# "Node 'grade_documents':"
# '\n---\n'
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS GROUNDED IN DOCUMENTS---
# ---GRADE GENERATION vs QUESTION---
# ---DECISION: GENERATION DOES NOT ADDRESS QUESTION---
# "Node 'generate':"
# '\n---\n'
# ('According to the provided context, which appears to be a snippet from '
#  "Apple's Q3 2022 Form 10-Q document, the effective tax rate on foreign "
#  'earnings is mentioned as one of the factors affecting their tax situation. '
#  "However, for a direct answer to your question about Apple's effective tax "
#  "rate, I don't see specific details in the provided context.\n"
#  '\n'
#  'But, considering general knowledge and typical financial reporting '
#  'practices, companies like Apple usually report their effective tax rates in '
#  "their quarterly or annual reports. If you're looking for the most accurate "
#  "and up-to-date information on Apple's effective tax rate, I recommend "
#  'checking their latest Form 10-Q or Form 10-K filings with the U.S. '
#  'Securities and Exchange Commission (SEC) or visiting their official investor '
#  'relations website.\n'
#  '\n'
#  'In general knowledge terms, companies often discuss their tax rates in '
#  'relation to their overall profitability and how taxes affect their bottom '
#  'line. The effective tax rate is a measure of what percentage of their income '
#  'they actually pay in taxes after accounting for various tax credits and '
#  "deductions. It's an important metric for investors and analysts to "
#  "understand a company's financial health and strategy.\n"
#  '\n'
#  "If you're looking for the specific number, I'd suggest checking Apple's "
#  'latest SEC filings or their investor relations website for the most current '
#  'information on their effective tax rate.')
# ---TRANSFORM QUERY---
# "Node 'transform_query':"
# '\n---\n'
# ---RETRIEVE---
# "Node 'retrieve':"
# '\n---\n'
# ---CHECK DOCUMENT RELEVANCE TO QUESTION---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT NOT RELEVANT---
# ---GRADE: DOCUMENT NOT RELEVANT---
# ---GRADE: DOCUMENT NOT RELEVANT---
# ---ASSESS GRADED DOCUMENTS---
# ---DECISION: GENERATE---
# "Node 'grade_documents':"
# '\n---\n'
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS GROUNDED IN DOCUMENTS---
# ---GRADE GENERATION vs QUESTION---
# ---DECISION: GENERATION DOES NOT ADDRESS QUESTION---
# "Node 'generate':"
# '\n---\n'
# ('Based on the context provided, I would answer the rewritten question as '
#  'follows:\n'
#  '\n'
#  'The average effective corporate tax rate paid by Apple is not explicitly '
#  'stated in the given snippet. However, we can infer that the effective tax '
#  'rate on foreign earnings mentioned in the document might be relevant to '
#  'answering this question.\n'
#  '\n'
#  'According to the snippet, the effective tax rate on foreign earnings was '
#  "partially offset by state income taxes. While we don't have a specific "
#  "average effective corporate tax rate for Apple, we can assume that it's "
#  'likely influenced by factors such as the U.S. federal R&D tax credit and '
#  'state income taxes.\n'
#  '\n'
#  'To provide a more accurate answer, I would recommend searching for '
#  "additional information on Apple's corporate tax rates in their financial "
#  'reports or other reliable sources.')
# ---TRANSFORM QUERY---
# "Node 'transform_query':"
# '\n---\n'
# ---RETRIEVE---
# "Node 'retrieve':"
# '\n---\n'
# ---CHECK DOCUMENT RELEVANCE TO QUESTION---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT NOT RELEVANT---
# ---GRADE: DOCUMENT NOT RELEVANT---
# ---GRADE: DOCUMENT NOT RELEVANT---
# ---ASSESS GRADED DOCUMENTS---
# ---DECISION: GENERATE---
# "Node 'grade_documents':"
# '\n---\n'
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS GROUNDED IN DOCUMENTS---
# ---GRADE GENERATION vs QUESTION---
# ---DECISION: GENERATION DOES NOT ADDRESS QUESTION---
# "Node 'generate':"
# '\n---\n'
# ("Based on the context provided, which includes information about Apple's Q3 "
#  '2022 Form 10-Q document, I can infer that the document discusses corporate '
#  'tax rates among other things.\n'
#  '\n'
#  'Given this context and your rewritten question optimized for vectorstore '
#  'retrieval:\n'
#  '\n'
#  '"Corporate tax rates of companies like Apple: what is the typical rate paid '
#  'by them?"\n'
#  '\n'
#  'I would answer as follows:\n'
#  '\n'
#  'The typical corporate tax rate paid by companies like Apple varies depending '
#  'on several factors, including their global operations, income sources, and '
#  'tax jurisdictions. However, based on publicly available information and '
#  'industry standards, here are some general insights:\n'
#  '\n'
#  '1. **Effective Tax Rate (ETR):** The ETR is a measure of the average tax '
#  'rate paid by a company over a specific period. For Apple, in Q3 2022, the '
#  'effective tax rate on foreign earnings was mentioned as part of their '
#  'financial report. However, without access to the exact figure from that '
#  'document, I can only speculate based on general knowledge.\n'
#  '\n'
#  'Typically, multinational corporations like Apple have complex tax structures '
#  'involving various jurisdictions and income streams. Their ETRs can be '
#  'influenced by factors such as tax credits for research and development '
#  '(R&D), share-based compensation benefits, and state income taxes, among '
#  'others.\n'
#  '\n'
#  '2. **Global Corporate Tax Rates:** The global corporate tax rate varies '
#  'significantly across countries. Most countries have a standard corporate tax '
#  'rate that applies to profits earned within their jurisdiction. However, the '
#  'effective tax rate can be lower due to various deductions and credits '
#  'available under tax laws.\n'
#  '\n'
#  'For instance, in 2022, the U.S. federal corporate income tax rate was 21%. '
#  "However, this is just one component of a company's overall tax liability, "
#  'which also includes state taxes, foreign taxes, and other local levies.\n'
#  '\n'
#  '3. **Industry Standards:** The typical corporate tax rate for tech companies '
#  'like Apple can be lower than that of other sectors due to several factors:\n'
#  '   - **Tax Credits:** Companies in the tech sector often benefit from R&D '
#  'tax credits, which can significantly reduce their tax liability.\n'
#  '   - **Global Operations:** Tech giants have extensive global operations, '
#  'allowing them to distribute profits across jurisdictions with favorable tax '
#  'regimes.\n'
#  '   - **Share-Based Compensation:** The use of share-based compensation plans '
#  "can also impact a company's tax rate by reducing the amount of cash paid out "
#  'in salaries and increasing the value of shares.\n'
#  '\n'
#  'Given these considerations, while specific figures for Apple are not '
#  'provided here, it is reasonable to infer that their effective corporate tax '
#  'rate could be lower than the standard U.S. federal corporate income tax rate '
#  'due to various tax benefits and credits available to them.\n'
#  '\n'
#  "For a more precise answer, direct access to Apple's financial reports or "
#  'consulting with a tax professional would be necessary.')
# ---TRANSFORM QUERY---
# "Node 'transform_query':"
# '\n---\n'
# ---RETRIEVE---
# "Node 'retrieve':"
# '\n---\n'
# ---CHECK DOCUMENT RELEVANCE TO QUESTION---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT NOT RELEVANT---
# ---GRADE: DOCUMENT NOT RELEVANT---
# ---GRADE: DOCUMENT NOT RELEVANT---
# ---ASSESS GRADED DOCUMENTS---
# ---DECISION: GENERATE---
# "Node 'grade_documents':"
# '\n---\n'
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS GROUNDED IN DOCUMENTS---
# ---GRADE GENERATION vs QUESTION---
# ---DECISION: GENERATION DOES NOT ADDRESS QUESTION---
# "Node 'generate':"
# '\n---\n'
# ("Based on the context provided, which mentions Apple's Q3 2022 Form 10-Q "
#  'document, I can infer that the average corporate tax rates paid by '
#  'multinational tech companies like Apple, Google, and Amazon are likely to be '
#  'discussed in this document.\n'
#  '\n'
#  'However, without direct access to the content of the document or a specific '
#  'section within it that discusses tax rates, I can only make an educated '
#  'guess. \n'
#  '\n'
#  'From my general knowledge base, I know that multinational corporations often '
#  'have complex financial structures and may take advantage of various tax '
#  'benefits and credits available to them. This can result in lower effective '
#  'corporate tax rates compared to smaller businesses or individual taxpayers.\n'
#  '\n'
#  'Given the context, here are some possible answers:\n'
#  '\n'
#  "1. **Effective Tax Rate Disclosure**: The document might disclose Apple's "
#  'effective tax rate for Q3 2022, which could be a good starting point for '
#  'estimating the average corporate tax rate paid by multinational tech '
#  'companies.\n'
#  '2. **Tax Benefits and Credits**: The document may discuss specific tax '
#  'benefits or credits that Apple has taken advantage of, such as the U.S. '
#  'federal R&D tax credit mentioned in the context. This information could '
#  'provide insight into how these companies manage their tax liabilities.\n'
#  '3. **Industry Average Tax Rates**: While not directly stated in the provided '
#  "context, it's possible that the document might discuss industry-wide average "
#  'corporate tax rates for tech companies like Apple, Google, and Amazon.\n'
#  '\n'
#  'To accurately answer your revised question, I would need direct access to '
#  "the content of Apple's Q3 2022 Form 10-Q document or a comprehensive dataset "
#  'containing financial information about these multinational tech companies.')
# ---TRANSFORM QUERY---
# "Node 'transform_query':"
# '\n---\n'
# ---RETRIEVE---
# "Node 'retrieve':"
# '\n---\n'
# ---CHECK DOCUMENT RELEVANCE TO QUESTION---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT NOT RELEVANT---
# ---GRADE: DOCUMENT NOT RELEVANT---
# ---GRADE: DOCUMENT NOT RELEVANT---
# ---ASSESS GRADED DOCUMENTS---
# ---DECISION: GENERATE---
# "Node 'grade_documents':"
# '\n---\n'
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS GROUNDED IN DOCUMENTS---
# ---GRADE GENERATION vs QUESTION---
# ---DECISION: GENERATION ADDRESSES QUESTION---
# "Node 'generate':"
# '\n---\n'
# ('Based on the context provided, which appears to be a snippet from Apple '
#  "Inc.'s Q3 2022 Form 10-Q document, we can infer some information about the "
#  'typical corporate tax burdens of large tech conglomerates like Apple. '
#  "However, it's essential to note that this is just one example and might not "
#  'fully represent all large tech companies globally.\n'
#  '\n'
#  'From the provided context:\n'
#  '\n'
#  '1. **Effective Tax Rate on Foreign Earnings**: The mention of an "effective '
#  'tax rate on foreign earnings" suggests that these companies have significant '
#  'international operations, leading to a complex tax situation due to varying '
#  'tax rates across different countries. This implies that their global tax '
#  'burden is influenced by the tax laws and rates in each country where they '
#  'operate.\n'
#  '\n'
#  '2. **Tax Benefits from Share-Based Compensation**: The document mentions '
#  '"tax benefits from share-based compensation." This indicates that these '
#  'companies can benefit from tax deductions related to employee stock options '
#  'or other forms of equity compensation, which are common practices in tech '
#  'industries. This suggests a potential reduction in their overall tax burden '
#  'through legitimate tax planning strategies.\n'
#  '\n'
#  '3. **Impact of the U.S. Federal R&D Tax Credit**: The mention of "the impact '
#  'of the U.S. federal R&D tax credit" highlights that these companies can '
#  'benefit from specific tax credits designed to encourage research and '
#  'development activities within the United States. This is another example of '
#  'how large tech conglomerates might reduce their tax liability through '
#  'strategic use of available tax incentives.\n'
#  '\n'
#  '4. **State Income Taxes**: The document also mentions "state income taxes," '
#  'which indicates that, despite federal tax benefits or credits, these '
#  'companies still face state-level taxation on their earnings. This suggests a '
#  'continued exposure to tax burdens at the state level, even for large tech '
#  'conglomerates with significant global operations and tax planning '
#  'strategies.\n'
#  '\n'
#  'Considering this information in conjunction with broader knowledge about '
#  'corporate taxation:\n'
#  '\n'
#  '- **Global Tax Complexity**: Large tech conglomerates often have complex '
#  'international structures designed to minimize tax liabilities. However, '
#  'these structures can also lead to increased scrutiny from tax authorities '
#  'worldwide.\n'
#  '  \n'
#  '- **Tax Planning Strategies**: Companies like Apple engage in sophisticated '
#  'tax planning, which includes leveraging available credits and deductions '
#  '(like the R&D credit mentioned) to reduce their overall tax burden.\n'
#  '\n'
#  '- **State and Local Taxes**: Despite federal benefits or credits, companies '
#  'still face taxation at the state and local levels. This can vary '
#  'significantly depending on where they operate within a country.\n'
#  '\n'
#  'In summary, large tech conglomerates like Apple face a complex global tax '
#  'environment that includes varying effective tax rates on foreign earnings, '
#  'potential tax benefits from share-based compensation, impacts of specific '
#  'tax credits (like the U.S. federal R&D tax credit), and exposure to state '
#  'income taxes. Their typical corporate tax burdens are influenced by their '
#  'international operations, strategic use of tax incentives, and local '
#  'taxation laws.')
# ('Based on the context provided, which appears to be a snippet from Apple '
#  "Inc.'s Q3 2022 Form 10-Q document, we can infer some information about the "
#  'typical corporate tax burdens of large tech conglomerates like Apple. '
#  "However, it's essential to note that this is just one example and might not "
#  'fully represent all large tech companies globally.\n'
#  '\n'
#  'From the provided context:\n'
#  '\n'
#  '1. **Effective Tax Rate on Foreign Earnings**: The mention of an "effective '
#  'tax rate on foreign earnings" suggests that these companies have significant '
#  'international operations, leading to a complex tax situation due to varying '
#  'tax rates across different countries. This implies that their global tax '
#  'burden is influenced by the tax laws and rates in each country where they '
#  'operate.\n'
#  '\n'
#  '2. **Tax Benefits from Share-Based Compensation**: The document mentions '
#  '"tax benefits from share-based compensation." This indicates that these '
#  'companies can benefit from tax deductions related to employee stock options '
#  'or other forms of equity compensation, which are common practices in tech '
#  'industries. This suggests a potential reduction in their overall tax burden '
#  'through legitimate tax planning strategies.\n'
#  '\n'
#  '3. **Impact of the U.S. Federal R&D Tax Credit**: The mention of "the impact '
#  'of the U.S. federal R&D tax credit" highlights that these companies can '
#  'benefit from specific tax credits designed to encourage research and '
#  'development activities within the United States. This is another example of '
#  'how large tech conglomerates might reduce their tax liability through '
#  'strategic use of available tax incentives.\n'
#  '\n'
#  '4. **State Income Taxes**: The document also mentions "state income taxes," '
#  'which indicates that, despite federal tax benefits or credits, these '
#  'companies still face state-level taxation on their earnings. This suggests a '
#  'continued exposure to tax burdens at the state level, even for large tech '
#  'conglomerates with significant global operations and tax planning '
#  'strategies.\n'
#  '\n'
#  'Considering this information in conjunction with broader knowledge about '
#  'corporate taxation:\n'
#  '\n'
#  '- **Global Tax Complexity**: Large tech conglomerates often have complex '
#  'international structures designed to minimize tax liabilities. However, '
#  'these structures can also lead to increased scrutiny from tax authorities '
#  'worldwide.\n'
#  '  \n'
#  '- **Tax Planning Strategies**: Companies like Apple engage in sophisticated '
#  'tax planning, which includes leveraging available credits and deductions '
#  '(like the R&D credit mentioned) to reduce their overall tax burden.\n'
#  '\n'
#  '- **State and Local Taxes**: Despite federal benefits or credits, companies '
#  'still face taxation at the state and local levels. This can vary '
#  'significantly depending on where they operate within a country.\n'
#  '\n'
#  'In summary, large tech conglomerates like Apple face a complex global tax '
#  'environment that includes varying effective tax rates on foreign earnings, '
#  'potential tax benefits from share-based compensation, impacts of specific '
#  'tax credits (like the U.S. federal R&D tax credit), and exposure to state '
#  'income taxes. Their typical corporate tax burdens are influenced by their '
#  'international operations, strategic use of tax incentives, and local '
#  'taxation laws.')
